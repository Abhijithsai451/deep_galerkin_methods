# %%
import network
from heat_equation.trainer import DGMTrainer, DGMTrainer_2D
from heat_equation.visualize import *
from heat_equation.data_sampling import *
from heat_equation.utility_functions import *

# %% [markdown]
# # Deep Galerkin Method in 1D

# %%
lx_1d = 2.0
T_max = 2.0
bounds_1d = [[0.0, lx_1d]]

# PDE Constants (for Heat Equation: u_t = alpha * u_xx + f)
ALPHA = 0.01
PDE_CONSTANTS = {'alpha': ALPHA}

# Data Sizes
N_INT = 1500
N_IC = 400
N_BC =400

# %% [markdown]
# ## Functions to implement the internal and boundary conditions

# %%
def source_term_fn(t, x, alpha):
    # f(t,x) = u_t - alpha*u_xx (plug known solution into PDE)
    # u_t = -exp(-t)*sin(pi*x)
    # u_xx = -pi^2 * exp(-t) * sin(pi*x)
    return (-torch.exp(-t) + ALPHA * torch.pi**2 * torch.exp(-t)) * torch.sin(torch.pi * x)

def initial_condition_fn(x):
    # u(x, 0) = sin(pi*x)
    return torch.sin(torch.pi * x)

def boundary_condition_fn(t, x):
    # u(0, t) = u(1, t) = exp(-t)*sin(0 or pi) = 0
    return torch.zeros_like(t)

# %% [markdown]
# ## Data Preparation

# %%
# 1. Interior Data (t in [0, T_max], x in [0, lx_1d])
x_int, t_int = generate_domain_points(N_INT, bounds_1d, T_max)
f_tx = source_term_fn(t_int, x_int, ALPHA).to(device)
interior_data_1d = (t_int, x_int, f_tx)

# 2. Initial Condition Data (t = 0, x in [0, lx_1d])
x_ic = generate_ic_points(N_IC, bounds_1d)
t_ic = torch.zeros_like(x_ic[:, 0:1]).to(device)
u_ic = initial_condition_fn(x_ic).to(device)
ic_data_1d = (t_ic, x_ic, u_ic)

# 3. Boundary Condition Data (t in [0, T_max], x = 0 or 1)
x_bc = generate_boundary_points(N_BC, bounds_1d)
t_bc = torch.rand_like(x_bc[:, 0:1]) * T_max # Sample time for boundary points
u_bc = boundary_condition_fn(t_bc, x_bc).to(device)
bc_data_1d = (t_bc, x_bc, u_bc)

# %% [markdown]
# ## Visualizing the Sampled data

# %%
visualize_points_1d(x_int,x_bc, bounds_1d)

# %% [markdown]
# ## Neural Network initialization

# %%
num_layers = 5
nodes_per_layer = 64
learning_rate = 0.001
epochs = 5000

model = network.DGMNet(nodes_per_layer, num_layers, 1).to(device)

trainer = DGMTrainer(
    model=model,
    pde_constants=PDE_CONSTANTS,
    learning_rate=learning_rate
)

# %% [markdown]
# ## Training

# %%
trainer.train(
    epochs=epochs,
    interior_data=interior_data_1d,
    ic_data=ic_data_1d,
    bc_data=bc_data_1d,
    lambda_ic=50.0,
    lambda_bc=50.0
)
# Out:
# Starting training on mps. Interior: 1500, IC: 400, BC: 400 points.
# Epoch 100/5000 | Total Loss: 1.2075 | L_pde: 0.0349 | L_ic: 0.0144 | L_bc: 0.0090
# Epoch 200/5000 | Total Loss: 0.3308 | L_pde: 0.0103 | L_ic: 0.0042 | L_bc: 0.0022
# Epoch 300/5000 | Total Loss: 0.4934 | L_pde: 0.0055 | L_ic: 0.0057 | L_bc: 0.0040
# Epoch 400/5000 | Total Loss: 0.0336 | L_pde: 0.0031 | L_ic: 0.0005 | L_bc: 0.0001
# Epoch 500/5000 | Total Loss: 0.0121 | L_pde: 0.0021 | L_ic: 0.0001 | L_bc: 0.0001
# Epoch
| L_pde: 0.0002 | L_ic: 0.0000 | L_bc: 0.0000

# %% [markdown]
# ## Visualization

# %%
t_test_time = 2
visualize_solution(
    model=model,
    lx_1d=lx_1d,
    t_test=t_test_time,
    n_test_points=500
)

# %% [markdown]
# # Deep Galerkin Method in 2D

# %%
lx_2d = 2.0
ly_2d = 2.0
T_max = 2.0
bounds_2d = [[0.0, lx_2d],[0.0, ly_2d]]

# PDE Constants (for Heat Equation: u_t = alpha * u_xx + f)
ALPHA = 0.01
PDE_CONSTANTS = {'alpha': ALPHA}

# Data Sizes
N_INT = 2500
N_IC = 400
N_BC =400

# %% [markdown]
# ## Data Preparation

# %%
# 1. Interior Data (t in [0, T_max], x in [0, lx_1d])
spatial_coords, t_int = generate_domain_points(N_INT, bounds_2d, T_max)
x_int = spatial_coords[:, 0:1]
y_int = spatial_coords[:, 1:2]
f_txy = source_term_fn_2D(t_int, x_int, y_int, ALPHA).to(device)
interior_data = (t_int, x_int, y_int,  f_txy)

# 2. Initial Condition Data (t = 0, x in [0, lx_1d])
spatial_coords_ic = generate_ic_points(N_IC, bounds_2d)
x_ic = spatial_coords_ic[:, 0:1]
y_ic = spatial_coords_ic[:, 1:2]
t_ic = torch.zeros_like(x_ic[:, 0:1]).to(device)
u_ic = initial_condition_fn_2D(x_ic,y_ic).to(device)
ic_data = (t_ic, x_ic, y_ic, u_ic)

# 3. Boundary Condition Data (t in [0, T_max], x = 0 or 1)
spatial_coords_bc = generate_boundary_points(N_BC, bounds_2d)
x_bc = spatial_coords_bc[:, 0:1]
y_bc = spatial_coords_bc[:, 1:2]
t_bc = torch.rand_like(x_bc[:, 0:1]) * T_max # Sample time for boundary points
u_bc = boundary_condition_fn_2D(t_bc, x_bc, y_bc).to(device)
bc_data = (t_bc, x_bc,y_bc, u_bc)

# %% [markdown]
# ## Visualizing the sampled data

# %%
visualize_points_2d(spatial_coords, spatial_coords_bc, bounds_2d)

# %% [markdown]
# ## Neural Network Initialization

# %%
num_layers = 6
nodes_per_layer = 64
learning_rate = 0.001
epochs = 6000

model = network.DGMNet(nodes_per_layer, num_layers, 2).to(device)

trainer = DGMTrainer_2D(
    model=model,
    pde_constants=PDE_CONSTANTS,
    learning_rate=learning_rate
)

# %% [markdown]
# ## Training

# %%
trainer.train(
    epochs=epochs,
    interior_data=interior_data,
    ic_data=ic_data,
    bc_data=bc_data,
    lambda_ic=50.0,
    lambda_bc=50.0
)
# Out:
# Starting training on mps. Interior: 2500, IC: 400, BC: 400 points.
# Epoch 100/6000 | Total Loss: 1.4817 | L_pde: 0.0231 | L_ic: 0.0192 | L_bc: 0.0100
# Epoch 200/6000 | Total Loss: 0.4728 | L_pde: 0.0164 | L_ic: 0.0059 | L_bc: 0.0032
# Epoch 300/6000 | Total Loss: 0.3353 | L_pde: 0.0135 | L_ic: 0.0041 | L_bc: 0.0023
# Epoch 400/6000 | Total Loss: 0.4294 | L_pde: 0.0077 | L_ic: 0.0036 | L_bc: 0.0048
# Epoch 500/6000 | Total Loss: 0.0402 | L_pde: 0.0043 | L_ic: 0.0004 | L_bc: 0.0003
# Epoch 600/6000 | Total Loss: 0.0250 | L_pde: 0.0031 | L_ic: 0.0002 | L_bc: 0.0002
# Epoch 700/6000 | Total Loss: 0.0169 | L_pde: 0.0024 | L_ic: 0.0001 | L_bc: 0.0002
# Epoch 800/6000 | Total Loss: 0.0146 | L_pde: 0.0027 | L_ic: 0.0001 | L_bc: 0.0001
# Epoch
| L_ic: 0.0000 | L_bc: 0.0000
# Epoch 5300/6000 | Total Loss: 0.0019 | L_pde: 0.0010 | L_ic: 0.0000 | L_bc: 0.0000
# Epoch 5400/6000 | Total Loss: 0.0158 | L_pde: 0.0009 | L_ic: 0.0001 | L_bc: 0.0002
# Epoch 5500/6000 | Total Loss: 0.0014 | L_pde: 0.0007 | L_ic: 0.0000 | L_bc: 0.0000
# Epoch 5600/6000 | Total Loss: 0.0012 | L_pde: 0.0005 | L_ic: 0.0000 | L_bc: 0.0000
# Epoch 5700/6000 | Total Loss: 0.0010 | L_pde: 0.0005 | L_ic: 0.0000 | L_bc: 0.0000
# Epoch 5800/6000 | Total Loss: 0.0171 | L_pde: 0.0005 | L_ic: 0.0002 | L_bc: 0.0002
# Epoch 5900/6000 | Total Loss: 0.0009 | L_pde: 0.0004 | L_ic: 0.0000 | L_bc: 0.0000
# Epoch 6000/6000 | Total Loss: 0.0008 | L_pde: 0.0003 | L_ic: 0.0000 | L_bc: 0.0000

# %% [markdown]
# ## Visualization

# %%
visualize_2d(
    model=model,
    bounds=bounds_2d,
    t_test=t_test_time,
    n_grid=500
)

# %%
visualize_solution_2d(
    model=model,
    bounds=bounds_2d,
    t_test=t_test_time,
    n_grid=500
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 visualize_solution_2d(
#       2     model=model,
#       3     bounds=bounds_2d,
#       4     t_test=t_test_time,
#       5     n_grid=500
#       6 )
#
# File ~/PycharmProjects/deep_galerkin_methods_v2/visualize.py:290, in visualize_solution_2d(model, bounds, t_test, n_grid)
#     286 surf_exact_top = ax1.plot_wireframe(X, Y, u_exact_np, color= 'blue', linewidth=1.0, rstride=5, cstride=5)
#     287 # Legend for combined plot
#     288 ax1.legend(
#     289     handles=[
# --> 290         Patch(color='viridis', alpha=0.8, label='DGM Solution'),
#     291         Patch(color='blue', alpha=0.8, label='Analytical Solution')
#     292     ],
#     293     loc='upper right'
#     294 )
#     295 ax1.set_title(f'Combined DGM Solution vs Analytical Solution at Time $t = {t:.2f}$', fontsize=16)
#     296 ax1.set_xlabel('$x$')
#
# File ~/miniconda3/envs/dgm_v2/lib/python3.12/site-packages/matplotlib/patches.py:82, in Patch.__init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      78     if edgecolor is not None or facecolor is not None:
#      79         _api.warn_external(
#      80             "Setting the 'color' property will override "
#      81             "the edgecolor or facecolor properties.")
# ---> 82     self.set_color(color)
#      83 else:
#      84     self.set_edgecolor(edgecolor)
#
# File ~/miniconda3/envs/dgm_v2/lib/python3.12/site-packages/matplotlib/patches.py:419, in Patch.set_color(self, c)
#     406 def set_color(self, c):
#     407     """
#     408     Set both the edgecolor and the facecolor.
#     409
#    (...)    417         For setting the edge or face color individually.
#     418     """
# --> 419     self.set_facecolor(c)
#     420     self.set_edgecolor(c)
#
# File ~/miniconda3/envs/dgm_v2/lib/python3.12/site-packages/matplotlib/patches.py:404, in Patch.set_facecolor(self, color)
#     396 """
#     397 Set the patch face color.
#     398
#    (...)    401 color : :mpltype:`color` or None
#     402 """
#     403 self._original_facecolor = color
# --> 404 self._set_facecolor(color)
#
# File ~/miniconda3/envs/dgm_v2/lib/python3.12/site-packages/matplotlib/patches.py:392, in Patch._set_facecolor(self, color)
#     390     color = mpl.rcParams['patch.facecolor']
#     391 alpha = self._alpha if self._fill else 0
# --> 392 self._facecolor = colors.to_rgba(color, alpha)
#     393 self.stale = True
#
# File ~/miniconda3/envs/dgm_v2/lib/python3.12/site-packages/matplotlib/colors.py:317, in to_rgba(c, alpha)
#     315     rgba = None
#     316 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 317     rgba = _to_rgba_no_colorcycle(c, alpha)
#     318     try:
#     319         _colors_full_map.cache[c, alpha] = rgba
#
# File ~/miniconda3/envs/dgm_v2/lib/python3.12/site-packages/matplotlib/colors.py:394, in _to_rgba_no_colorcycle(c, alpha)
#     390             raise ValueError(
#     391                 f"Invalid string grayscale value {orig_c!r}. "
#     392                 f"Value must be within 0-1 range")
#     393         return c, c, c, alpha if alpha is not None else 1.
# --> 394     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     395 # turn 2-D array into 1-D array
#     396 if isinstance(c, np.ndarray):
#
# ValueError: Invalid RGBA argument: 'viridis'
